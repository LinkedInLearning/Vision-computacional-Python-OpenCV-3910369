# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("src/Red fox_LIL_191706.jpeg")

# %%
# cv2.imshow("Imagen", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(3583.5), np.float64(2239.5), np.float64(-0.5))
